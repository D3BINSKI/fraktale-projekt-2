# %% [markdown]
# # Alpha sssi dla procesu Levy'ego

# %%
from prometheus_client import samples
from pycopula.copula import GaussianCopula
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import levy_stable

# %% [markdown]
# W tej części skorzystamy z funckji levy_stable, w której parametr *H* jest równy *1/alpha

# %%
# Parameters for the alpha-stable distribution
alpha, beta = 1.5, 0  # Stability parameter (0 < alpha <= 2)
mu = 0       # Location parameter
sigma = 1   # Scale parameter

# Generate random samples
num_samples = 1000
samples1 = stats.levy_stable.rvs(alpha, beta, loc=mu, scale=sigma, size=num_samples)
samples2 = stats.levy_stable.rvs(alpha, beta, loc=mu, scale=sigma, size=num_samples)

fig, axs = plt.subplots(2, 1)

axs[0].plot(samples)
axs[0].set_title(f'Levy distribution (alpha={alpha})')
axs[0].set_xlabel('t')
axs[0].set_ylabel('Value')

# Plot the histogram of the samples
axs[1].hist(samples, bins=50, density=True)
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Probability density function

# %%
fig, ax = plt.subplots(1, 1)

x = np.linspace(levy_stable.ppf(0.01, alpha, beta),
                levy_stable.ppf(0.99, alpha, beta), 100)
ax.plot(x, levy_stable.pdf(x, alpha, beta),
       'r-', lw=5, alpha=0.6, label='levy_stable pdf')

rv = levy_stable(alpha, beta)
ax.plot(x, rv.pdf(x), 'k-', lw=2, label='frozen pdf')

ax.hist(samples, density=True, bins='auto', histtype='stepfilled', alpha=0.2)
ax.set_xlim([x[0], x[-1]])
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# Copula functions
